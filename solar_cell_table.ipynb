# %% [markdown]
# # Solar Cell Parameters — Rendered Table

# %%
import pandas as pd
from IPython.display import display

data = [
 ['Mono-Si (PERC/TOPCon)',38,0.72,0.83,24,'Mature commercial'],
 ['HJT Si',39,0.74,0.85,25.5,'High Voc'],
 ['Poly-Si',37,0.68,0.78,20,'Lower cost'],
 ['CdTe',28,0.85,0.78,21,'Temp stable'],
 ['CIGS',34,0.82,0.80,23,'Thin film'],
 ['Perovskite',24,1.15,0.85,25,'Fast improving'],
 ['Perovskite/Si Tandem',20,1.8,0.86,31,'Next gen'],
]

cols=['Material','Isc (mA/cm²)','Voc (V)','FF','Efficiency (%)','Notes']
df=pd.DataFrame(data,columns=cols)
display(df)
